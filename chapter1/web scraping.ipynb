# %%
import requests
from bs4 import BeautifulSoup
import csv
import json
url = "https://en.wikipedia.org/wiki/Web_scraping"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

headings = soup.find_all(["h2", "h3"])

references = []
for ref in soup.select("ol.references li cite a"):
    link = ref.get("href")
    if link:
        if link.startswith("/"):
            link = "https://en.wikipedia.org" + link
        references.append(link)
        
print("Total Headings:", len(data))
print("First 10 headings:")
for h in data[:10]:
    print("-", h)    
print("First 5 References:")
for r in references[:5]:
    print("-", r)
# Out:
# Total Headings: 20
# First 10 headings:
# - Contents
# - History
# - Techniques
# - Human copy-and-paste
# - Text pattern matching
# - HTTP programming
# - HTML parsing
# - DOM parsing
# - Vertical aggregation
# - Semantic annotation recognizing
# First 5 References:
# - https://doi.org/10.5334%2Fdsj-2021-024
# - https://en.wikipedia.org/wiki/Doi_(identifier)
# - https://doi.org/10.5334%2Fdsj-2021-024
# - https://en.wikipedia.org/wiki/ISSN_(identifier)
# - https://search.worldcat.org/issn/1683-1470
