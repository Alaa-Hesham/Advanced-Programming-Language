# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

title = soup.find("title").text
print("Page Title:", title)
# Out:
# Page Title: Example Domain

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all("a")

for link in links:
    print(link.get("href"))
# Out:
# https://iana.org/domains/example

# %%
from bs4 import BeautifulSoup

html = """
<table>
    <tr><th>Name</th><th>Age</th></tr>
    <tr><td>Alice</td><td>25</td></tr>
    <tr><td>Bob</td><td>30</td></tr>
</table>
"""

soup = BeautifulSoup(html, "html.parser")
rows = soup.find_all("tr")

for row in rows:
    cols = [cell.text for cell in row.find_all(["th", "td"])]
    print(cols)
# Out:
# ['Name', 'Age']
# ['Alice', '25']
# ['Bob', '30']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()

driver.get("https://www.google.com")

search = driver.find_element(By.NAME, "q")
search.send_keys("Python Web Scraping")
search.send_keys(Keys.RETURN)

time.sleep(2)

print(driver.title)

driver.quit()
# Out:
# https://www.google.com/search?q=Python+Web+Scraping&sca_esv=bdfa73f17f6789a5&source=hp&ei=Ciw3aarMLaam2roPrfuQ4AU&iflsig=AOw8s4IAAAAAaTc6GgXvPeTdMxuLqwIMbIc5nFuLisTF&ved=0ahUKEwiq-Zve4a6RAxUmk1YBHa09BFwQ4dUDCA4&uact=5&oq=Python+Web+Scraping&gs_lp=&sclient=gws-wiz&sei=DCw3aYriJIaN9u8P5Zi9mQU

# %%
from bs4 import BeautifulSoup
import csv

html = """
<ul>
    <li>Apple</li>
    <li>Banana</li>
    <li>Cherry</li>
</ul>
"""

soup = BeautifulSoup(html, "html.parser")

fruits = [li.text for li in soup.find_all("li")]

with open("fruits.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Fruit"])
    for fruit in fruits:
        writer.writerow([fruit])
for fruit in fruits:
 print(fruit)
# Out:
# Apple
# Banana
# Cherry
